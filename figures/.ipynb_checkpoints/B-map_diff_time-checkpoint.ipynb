# %%
import time
import scipy.stats
import numpy as np
import pandas
import plotly.express as px
import matplotlib.pylab as plt, matplotlib
import bgshr

plt.rcParams["legend.title_fontsize"] = "xx-small"
matplotlib.rc("xtick", labelsize=7)
matplotlib.rc("ytick", labelsize=7)
matplotlib.rc("axes", labelsize=8)
matplotlib.rc("axes", titlesize=8)
matplotlib.rc("legend", fontsize=6)
plt.rcParams['legend.title_fontsize'] = 'xx-small'

# %%
two_epochs_bot = np.load('diff_time_bottleneck.npy')
two_epochs_exp = np.load('diff_time_expansion.npy')

# %%
df = pandas.DataFrame({'Bottleneck': two_epochs_bot, 'Expansion': two_epochs_exp})
df.plot(xlabel="Time (Generations ago / 500)", ylabel="Normalized RMSE").legend(loc='best')
plt.savefig(f"B-eq_RMSE_2_epochs.pdf", dpi=500)

# %%
four_epochs = np.load('diff_time_cousins.npy')

# %%
df = pandas.DataFrame({'Cousins et al': four_epochs})
df.plot(xlabel="Time (Generations ago / 500)", ylabel="Normalized RMSE").legend(loc='best')
plt.savefig(f"B-eq_RMSE_4_epochs.pdf", dpi=500)
